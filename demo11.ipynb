# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#     ResponseId                                         MainBranch  \
# 17          18                     I am a developer by profession
# 58          59  I am not primarily a developer, but I write co...
# 75          76                              I am learning to code
# 89          90                              I am learning to code
# 96          97                     I am a developer by profession
#
#                 Age                                         Employment  \
# 17  18-24 years old  Independent contractor, freelancer, or self-em...
# 58  18-24 years old                                 Student, full-time
# 75  25-34 years old                 Not employed, but looking for work
# 89  25-34 years old                                Employed, full-time
# 96  25-34 years old                                Employed, full-time
#
#    RemoteWork   Check                                   CodingActivities  \
# ...

# %%
#to convert in csv format
#to_csv('file path with new file name')
india_df.to_csv('data/CSVFormat.csv')

# %%
#want to seprate words with your choice
india_df.to_csv('data/SepFormat.tsv', sep='\t')

# %%
#to convert in excel format

india_df.to_excel('data/ExcelFormat.xlsx')

# %%
test = pd.read_excel('data/ExcelFormat.xlsx',index_col='ResponseId')

# %%
test.head()
# Out:
#             Unnamed: 0                                         MainBranch  \
# ResponseId
# 18                  17                     I am a developer by profession
# 59                  58  I am not primarily a developer, but I write co...
# 76                  75                              I am learning to code
# 90                  89                              I am learning to code
# 97                  96                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# ...

# %%
#convert to json format

india_df.to_json('data/JSONFormat.json')

# %%
test1 = pd.read_json('data/JSONFormat.json')
test1.head()
# Out:
#     ResponseId                                         MainBranch  \
# 17          18                     I am a developer by profession
# 58          59  I am not primarily a developer, but I write co...
# 75          76                              I am learning to code
# 89          90                              I am learning to code
# 96          97                     I am a developer by profession
#
#                 Age                                         Employment  \
# 17  18-24 years old  Independent contractor, freelancer, or self-em...
# 58  18-24 years old                                 Student, full-time
# 75  25-34 years old                 Not employed, but looking for work
# 89  25-34 years old                                Employed, full-time
# 96  25-34 years old                                Employed, full-time
#
#    RemoteWork   Check                                   CodingActivities  \
# ...
