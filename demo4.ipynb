# %%
import pandas as pd
df = pd.read_csv("data/survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
filt = (df['CodingActivities']=='Hobby') & (df['EdLevel']=='Primary/elementary school')
filt1 = (df['CodingActivities']=='Hobby') | (df['EdLevel']=='Primary/elementary school')

# %%
df.loc[filt,'Age']
# Out:
# ResponseId
# 1        Under 18 years old
# 2121        18-24 years old
# 2213     Under 18 years old
# 2704        18-24 years old
# 4011        25-34 years old
#                 ...
# 61465       25-34 years old
# 61675    Under 18 years old
# 61955       18-24 years old
# 62050       18-24 years old
# 64469    Under 18 years old
# Name: Age, Length: 78, dtype: object

# %%
df.loc[filt1,['Age','LearnCode']]
# Out:
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 6           Under 18 years old
# 9              45-54 years old
# 16             45-54 years old
# 17          Under 18 years old
# ...                        ...
# 65402          25-34 years old
# 65409          25-34 years old
# 65424          18-24 years old
# 65425          25-34 years old
# 65435          25-34 years old
#
#                                                     LearnCode
# ResponseId
# 1                                      Books / Physical media
# 6           School (i.e., University, College, etc);Online...
# 9           Books / Physical media;Other online resources ...
# 16          Books / Physical media;On the job training;Oth...
# 17          Books / Physical media;Other online resources ...
# ...                                                       ...
# 65402       Colleague;On the job training;Other online res...
# ...

# %%
filt2 = df['LearnCode'].str.contains('Books',na=False)
filt2
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4        False
# 5        False
#          ...
# 65433    False
# 65434    False
# 65435    False
# 65436    False
# 65437    False
# Name: LearnCode, Length: 65437, dtype: bool

# %%
df.loc[filt2,'LearnCode']
# Out:
# ResponseId
# 1                                   Books / Physical media
# 2        Books / Physical media;Colleague;On the job tr...
# 3        Books / Physical media;Colleague;On the job tr...
# 9        Books / Physical media;Other online resources ...
# 11       Books / Physical media;Other online resources ...
#                                ...
# 65406    Books / Physical media;Colleague;On the job tr...
# 65412    Books / Physical media;On the job training;Oth...
# 65413    Books / Physical media;Online Courses or Certi...
# 65429    Books / Physical media;Colleague;Other online ...
# 65432    Books / Physical media;Colleague;On the job tr...
# Name: LearnCode, Length: 30392, dtype: object
